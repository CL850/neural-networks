# %% [markdown]
# <html> <h1 style="font-style:bold; color:blue;"> Neural Computing and Deep Learning </h1> </html>

# %% [markdown]
# <html> <h1 style="font-style:italic; color:blue;"> Week-6 </h1> </html>

# %% [markdown]
# <html> <h2 style="font-style:italic; color:blue;"> RNN for Time Series </h2> </html>
#
#
# RNNs are used for sequence modelling. This tutorial will look at time series data to be modelled and predicted using RNNs.

# %%
# Import Libraries (pandas, numpy, matplotlib)

import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# ### Data
#
# We will use retail data for time-series modeling.
#
# Link to the dataset:
#  https://fred.stlouisfed.org/series/MRTSSM448USN
#
# Information about the Advance Monthly Retail Sales Survey can be found on the Census website at:
# https://www.census.gov/retail/marts/about_the_surveys.html
#
# Release: Advance Monthly Sales for Retail and Food Services
# Units:  Millions of Dollars, Not Seasonally Adjusted
# Frequency:  Monthly
#
# Suggested Citation:
# U.S. Census Bureau, Advance Retail Sales: Clothing and Clothing Accessory Stores [RSCCASN], retrieved from FRED, Federal Reserve Bank of St. Louis; https://fred.stlouisfed.org/series/RSCCASN, January 25, 2025.

# %% [markdown]
# ##### Read data first -  Use index_col = 'DATE' and 'parse_dates = True' as a parameter.

# %% [markdown]
# _________________![image.png](attachment:d2f728cb-4c14-4ede-9ca4-3210197b3bf5.png)

# %%
import pandas as pd

df = pd.read_csv(
    'MRTSSM448USN_24-1.csv',
    index_col='observation_date',       
    parse_dates=['observation_date']    
)

# %%
#pd.read_csv

# %%
# Print the first few rows of data
df.head()
# Out:
#                   MRTSSM448USN
# observation_date
# 1992-01-01                6938
# 1992-02-01                7524
# 1992-03-01                8475
# 1992-04-01                9401
# 1992-05-01                9558

# %%
# Out:
#                   MRTSSM448USN
# observation_date
# 1992-01-01                6938
# 1992-02-01                7524
# 1992-03-01                8475
# 1992-04-01                9401
# 1992-05-01                9558

# %% [markdown]
# _______________![image.png](attachment:7e472928-25f6-4701-891d-d6e138d8301c.png)

# %%
df.tail()
# Out:
#                   MRTSSM448USN
# observation_date
# 2024-08-01               27215
# 2024-09-01               23088
# 2024-10-01               25318
# 2024-11-01               29762
# 2024-12-01               41199

# %%
# Out:
#                   MRTSSM448USN
# observation_date
# 2024-08-01               27215
# 2024-09-01               23088
# 2024-10-01               25318
# 2024-11-01               29762
# 2024-12-01               41199

# %% [markdown]
# Does the sales column has any name?
#
# If no, set the name of the colum as 'Sales'.

# %%
# Set name of column as 'Sales'. Use - df.columns 
df.columns = ['Sales']
print(df.columns)
# Out:
# Index(['Sales'], dtype='object')

# %%
df.head()
# Out:
#                   Sales
# observation_date
# 1992-01-01         6938
# 1992-02-01         7524
# 1992-03-01         8475
# 1992-04-01         9401
# 1992-05-01         9558

# %% [markdown]
# Plot your data - Year vs Sales
#
# hint: use df.plot  and plt.show()

# %% [markdown]
# ____________![image.png](attachment:805024e0-d954-465a-b7e2-ddfb909885ff.png)

# %%
df.plot(figsize=(12,8))
plt.show()

# %% [markdown]
# ### Train Test Split
#
# We will use the last 1.5 years (18 months) samples for testing. The rest is for training

# %% [markdown]
# ______________![image.png](attachment:e38848db-d649-4cf7-a213-65b7f4afb347.png)

# %%
test_size = 18
test_size
# Out:
# 18

# %%
# Out:
# 18

# %% [markdown]
# __________![image.png](attachment:2c857cf3-2515-4517-9d3d-db350c691bf7.png)

# %%
data_length = len(df)
data_length
# Out:
# 396

# %%
# Out:
# 396

# %% [markdown]
# __________________![image.png](attachment:f8eaa367-9088-41f8-8b8b-9d268a0818ed.png)

# %%
train_size = data_length - test_size
train_size
# Out:
# 378

# %%
# Out:
# 378

# %% [markdown]
# Now, we will find the indexes of the test data. Remember, these are the last 18 indexes in the pandas dataframe.

# %% [markdown]
# ____________________![image.png](attachment:91a08444-364a-40fa-a0c3-839197c15995.png)

# %%
test_index = train_size
test_index
# Out:
# 378

# %%
# Out:
# 378

# %% [markdown]
# Next, we will separate train and test datasets.

# %% [markdown]
# _________________________![image.png](attachment:3ae07221-155f-4716-9ea4-7484eb94dab4.png)

# %%
train = df.iloc[:test_index]
train
# Out:
#                   Sales
# observation_date
# 1992-01-01         6938
# 1992-02-01         7524
# 1992-03-01         8475
# 1992-04-01         9401
# 1992-05-01         9558
# ...                 ...
# 2023-02-01        20666
# 2023-03-01        24510
# 2023-04-01        24232
# 2023-05-01        26096
# 2023-06-01        24364
#
# [378 rows x 1 columns]

# %%
# Out:
#                   Sales
# observation_date
# 1992-01-01         6938
# 1992-02-01         7524
# 1992-03-01         8475
# 1992-04-01         9401
# 1992-05-01         9558
# ...                 ...
# 2023-02-01        20666
# 2023-03-01        24510
# 2023-04-01        24232
# 2023-05-01        26096
# 2023-06-01        24364
#
# [378 rows x 1 columns]

# %%
# Store everything from test_index to the last sample in the test variable 
# Hint - Use df.iloc

test = df.iloc[test_index:]
test
# Out:
#                   Sales
# observation_date
# 2023-07-01        24911
# 2023-08-01        26657
# 2023-09-01        23332
# 2023-10-01        23933
# 2023-11-01        28580
# 2023-12-01        40684
# 2024-01-01        19188
# 2024-02-01        22005
# 2024-03-01        24986
# 2024-04-01        23993
# 2024-05-01        27562
# 2024-06-01        25121
# 2024-07-01        25453
# 2024-08-01        27215
# 2024-09-01        23088
# 2024-10-01        25318
# 2024-11-01        29762
# 2024-12-01        41199

# %%
# Out:
#                   Sales
# observation_date
# 2023-07-01        24911
# 2023-08-01        26657
# 2023-09-01        23332
# 2023-10-01        23933
# 2023-11-01        28580
# 2023-12-01        40684
# 2024-01-01        19188
# 2024-02-01        22005
# 2024-03-01        24986
# 2024-04-01        23993
# 2024-05-01        27562
# 2024-06-01        25121
# 2024-07-01        25453
# 2024-08-01        27215
# 2024-09-01        23088
# 2024-10-01        25318
# 2024-11-01        29762
# 2024-12-01        41199

# %%
# Print the size of the train data

print(train.size)

# Print the size of the test data

print(test.size)
# Out:
# 378
# 18

# %%
# Out:
# 378
# 18

# %% [markdown]
# ### In Neural Networks, we need to Scale Data between 0-1

# %% [markdown]
# ___________________![image.png](attachment:427170b6-570a-4740-b005-cd2e88a0f8b6.png)

# %%
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# _______________________![image.png](attachment:b5ef2c4e-c013-4af5-9320-c48c58751458.png)

# %%
scaler = MinMaxScaler()
scaler.fit(train)
# Out:
# MinMaxScaler()

# %%
# Out:
# MinMaxScaler()

# %% [markdown]
# __________________![image.png](attachment:4e64d75b-6582-4975-bd2f-3881d943301d.png)

# %%
scaled_train = scaler.transform(train)
scaled_test = scaler.transform(test)

# %%
# Check if the data has been scaled properly
# Print max and min for train and test

print(scaled_test.max())
print(scaled_test.min())
print(scaled_train.max())
print(scaled_train.min())
# Out:
# 1.0530599939704552
# 0.44980403979499545
# 1.0
# 0.0

# %%
# Out:
# 1.0
# 1.0530599939704552
# 0.0
# 0.44980403979499545

# %% [markdown]
# ## Time Series Generator
#
# This class takes in a sequence of data points gathered at
# equal intervals, along with time series parameters such as
# stride, length of history, etc., to produce batches for
# training/validation.
#
# #### Arguments
#     data: Indexable generator (such as list or Numpy array)
#         containing consecutive data points (timesteps).
#         The data should be at 2D, and axis 0 is expected
#         to be the time dimension.
#     targets: Targets corresponding to timesteps in `data`.
#         It should have same length as `data`.
#     length: Length of the output sequences (in number of timesteps).
#     sampling_rate: Period between successive individual timesteps
#         within sequences. For rate `r`, timesteps
#         `data[i]`, `data[i-r]`, ... `data[i - length]`
#         are used for create a sample sequence.
#     stride: Period between successive output sequences.
#         For stride `s`, consecutive output samples would
#         be centered around `data[i]`, `data[i+s]`, `data[i+2*s]`, etc.
#     start_index: Data points earlier than `start_index` will not be used
#         in the output sequences. This is useful to reserve part of the
#         data for test or validation.
#     end_index: Data points later than `end_index` will not be used
#         in the output sequences. This is useful to reserve part of the
#         data for test or validation.
#     shuffle: Whether to shuffle output samples,
#         or instead draw them in chronological order.
#     reverse: Boolean: if `true`, timesteps in each output sample will be
#         in reverse chronological order.
#     batch_size: Number of timeseries samples in each batch
#         (except maybe the last one).

# %% [markdown]
# ### We will use 12 months as input and then predict the next month out

# %% [markdown]
# _____________________![image.png](attachment:75eeec67-065a-4084-9a2b-c10207e20cba.png)

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
#TimeseriesGenerator?

# %% [markdown]
# _________________![image.png](attachment:280feffa-2228-4562-9b29-005f579078ef.png)

# %%
length = 12 
generator = TimeseriesGenerator(scaled_train, scaled_train, length=length, batch_size=1)

# %% [markdown]
# _______________________![image.png](attachment:6525f6be-465f-4f4c-8198-cad63a006c9b.png)

# %%
X,y = generator[0]

print(f'Given the Array: \n{X.flatten()}')
print(f'Predict this y: \n {y}')
# Out:
# Given the Array:
# [0.11406802 0.13012854 0.15619262 0.18157152 0.18587442 0.17556938
#  0.17340423 0.21204813 0.18628553 0.20494971 0.23052046 0.42807027]
# Predict this y:
#  [[0.12952558]]

# %%
# Out:
# Given the Array:
# [0.11406802 0.13012854 0.15619262 0.18157152 0.18587442 0.17556938
#  0.17340423 0.21204813 0.18628553 0.20494971 0.23052046 0.42807027]
# Predict this y:
#  [[0.12952558]]

# %% [markdown]
# ### Create the Model

# %% [markdown]
# __________________![image.png](attachment:dcf392e0-03bf-4b10-ba27-164aacc0d43d.png)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import SimpleRNN
from tensorflow.keras.layers import GRU

import tensorflow as tf

# %% [markdown]
# ________________![image.png](attachment:aef51a9d-f017-45c3-a12d-2a77630a3721.png)

# %%
n_features = 1
n_features
# Out:
# 1

# %%
# Out:
# 1

# %% [markdown]
# ## Define your own models.
#
# Use 1. SimpleRNN, LSTM, or GRU neural network.
#
# APIs:
# https://keras.io/api/layers/recurrent_layers/

# %%
# Your code to create your own model
# use input_shape=(length, n_features)
# use model.add(Dense(1)) because it is the regression task
 

model = Sequential([
    SimpleRNN(32, activation='tanh', input_shape=(length, n_features), return_sequences=True),
    SimpleRNN(16, activation='tanh'),
    Dense(1) 
])
# Out:
# C:\Users\Kalche\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the next cell using 'Ctrl' + 'Enter' </h4> </html>

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)               │ (None, 12, 32)              │           1,088 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ simple_rnn_1 (SimpleRNN)             │ (None, 16)                  │             784 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              17 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,889 (7.38 KB)
#  Trainable params: 1,889 (7.38 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# _____________________![image.png](attachment:5f040382-1621-443b-87a6-48ad7c9c995f.png)

# %%
model.compile(optimizer='adam', loss='mse')

# %% [markdown]
# ### EarlyStopping and creating a Validation Generator
#
# NOTE: The scaled_test dataset size MUST be greater than your length chosen for your batches.
#
# Review the video on the Week-6 page for more info on this.

# %% [markdown]
# ____________________![image.png](attachment:1e369f4c-671b-4fde-86e3-bd98c23286a9.png)

# %%
validation_generator = TimeseriesGenerator(scaled_test, scaled_test, length=length, batch_size=1)

# %% [markdown]
# ___________________![image.png](attachment:6eace136-bdc8-439c-9221-0892959c5cf8.png)

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Your code to create an object early-stop

# Use the patience parameter equal to the last digit in your SID.
# However,
# If the last digit of your SID = 0, then assign patience=10
# If the last digit of your SID = 1, then assign patience=11
# If the last digit of your SID = 2, then assign patience=12
# If the last digit of your SID = 3, then assign patience=13

# For example, your SID = 22984879, then patience=9
# One more example: your SID = 22984883, then patience=13

# LAST_DIGIT_IN_YOUR_SID = 4

early_stop = EarlyStopping(monitor='val_loss',patience=14)

# %% [markdown]
# _____________________![image.png](attachment:e0ecd664-7df5-4386-a700-adb2228bf254.png)

# %%
history = model.fit(generator, epochs=20, validation_data=validation_generator, callbacks=[early_stop])
# Out:
# Epoch 1/20
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.0139 - val_loss: 0.0248
# Epoch 2/20
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0072 - val_loss: 0.0080
# Epoch 3/20
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0073 - val_loss: 0.0094
# Epoch 4/20
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0070 - val_loss: 0.0018
# Epoch 5/20
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0061 - val_loss: 0.0141
# Epoch 6/20
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0055 - val_loss: 0.0020
# Epoch 7/20
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0052 - val_loss: 0.0036
# Epoch 8/20
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0048 - val_loss: 0.0024
# Epoch 9/20
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0047 - val_loss: 0.0068
# Epoch 10/20
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0054 - val_loss: 0.0065
# Epoch 11/20
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0056 - val_loss: 0.0010
# Epoch 12/20
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0045 - val_loss: 0.0071
# Epoch 13/20
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0044 - val_loss: 0.0012
# Epoch 14/20
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0041 - val_loss: 0.0018
# Epoch 15/20
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0040 - val_loss: 0.0047
# Epoch 16/20
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0047 - val_loss: 0.0237
# Epoch 17/20
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0036 - val_loss: 0.0017
# Epoch 18/20
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0037 - val_loss: 0.0108
# Epoch 19/20
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0037 - val_loss: 0.0080
# Epoch 20/20
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0042 - val_loss: 0.0058

# %%
# Out:
# C:\Users\vital\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 16s 22ms/step - loss: 0.0364 - val_loss: 0.0283
# Epoch 2/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0124 - val_loss: 0.0153
# Epoch 3/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0118 - val_loss: 0.0010
# Epoch 4/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - loss: 0.0068 - val_loss: 0.0032
# Epoch 5/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 0.0047 - val_loss: 0.0127
# Epoch 6/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - loss: 0.0079 - val_loss: 0.0011
# Epoch 7/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0037 - val_loss: 0.0011
# Epoch 8/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - loss: 0.0043 - val_loss: 0.0015
# Epoch 9/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0046 - val_loss: 0.0026
# Epoch 10/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0042 - val_loss: 6.1039e-04
# Epoch 11/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 0.0049 - val_loss: 6.4973e-04
# Epoch 12/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 0.0033 - val_loss: 6.5717e-04
# Epoch 13/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - loss: 0.0031 - val_loss: 0.0065
# Epoch 14/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0042 - val_loss: 0.0013
# Epoch 15/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - loss: 0.0040 - val_loss: 0.0025
# Epoch 16/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - loss: 0.0035 - val_loss: 0.0023
# Epoch 17/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0026 - val_loss: 8.7657e-04
# Epoch 18/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0045 - val_loss: 8.2289e-04

# %% [markdown]
# _____________![image.png](attachment:00bc3c6b-8d83-4d5c-80cc-1f586fc18bb3.png)

# %%
losses = pd.DataFrame(model.history.history)
losses[:5]
# Out:
#        loss  val_loss
# 0  0.013906  0.024845
# 1  0.007195  0.007968
# 2  0.007291  0.009423
# 3  0.007020  0.001796
# 4  0.006060  0.014051

# %%
# the values may be different
# Out:
#        loss  val_loss
# 0  0.020090  0.028262
# 1  0.012648  0.015266
# 2  0.010198  0.001036
# 3  0.006880  0.003225
# 4  0.005237  0.012703

# %% [markdown]
# ___________________![image.png](attachment:f4e5651a-8770-46d6-80cd-ad7c715e6fe4.png)

# %%
losses.plot()
plt.show()

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the next cell using 'Ctrl' + 'Enter' </h4> </html>

# %%
# print Loss for the neural network training process

history_dict = history.history

acc_values = history_dict['loss']
val_acc_values = history_dict['val_loss']
epochs = range(1, len(acc_values) + 1)

plt.figure(num=1, figsize=(15,7))
plt.plot(epochs, acc_values, 'bo', label='Training loss')
plt.plot(epochs, val_acc_values, 'b', label='Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss (mse)')
plt.legend()

plt.show()

# %% [markdown]
# ### Evaluate on Test Data

# %% [markdown]
# ____________________![image.png](attachment:78ee4976-41bd-457c-8de2-ee2446e02523.png)

# %%
print(scaled_train[-15:])
# Out:
# [[0.61523282]
#  [0.64077617]
#  [0.5909502 ]
#  [0.59621235]
#  [0.62693562]
#  [0.55844547]
#  [0.58834653]
#  [0.69254803]
#  [1.        ]
#  [0.44788555]
#  [0.49031162]
#  [0.59566421]
#  [0.58804506]
#  [0.63913175]
#  [0.59166278]]

# %%
# Out:
# [[0.61523282]
#  [0.64077617]
#  [0.5909502 ]
#  [0.59621235]
#  [0.62693562]
#  [0.55844547]
#  [0.58834653]
#  [0.69254803]
#  [1.        ]
#  [0.44788555]
#  [0.49031162]
#  [0.59566421]
#  [0.58804506]
#  [0.63913175]
#  [0.59166278]]

# %% [markdown]
# ____________________![image.png](attachment:7c5efeb5-4631-462d-b593-f7ee0b22b63b.png)

# %%
first_eval_batch = scaled_train[-length:]
first_eval_batch
# Out:
# array([[0.59621235],
#        [0.62693562],
#        [0.55844547],
#        [0.58834653],
#        [0.69254803],
#        [1.        ],
#        [0.44788555],
#        [0.49031162],
#        [0.59566421],
#        [0.58804506],
#        [0.63913175],
#        [0.59166278]])

# %%
# Out:
# array([[0.59621235],
#        [0.62693562],
#        [0.55844547],
#        [0.58834653],
#        [0.69254803],
#        [1.        ],
#        [0.44788555],
#        [0.49031162],
#        [0.59566421],
#        [0.58804506],
#        [0.63913175],
#        [0.59166278]])

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the next cell using 'Ctrl' + 'Enter' </h4> </html>

# %%
n_input = 12
first_eval_batch = first_eval_batch.reshape((1, n_input, n_features))
first_eval_batch
# Out:
# array([[[0.59621235],
#         [0.62693562],
#         [0.55844547],
#         [0.58834653],
#         [0.69254803],
#         [1.        ],
#         [0.44788555],
#         [0.49031162],
#         [0.59566421],
#         [0.58804506],
#         [0.63913175],
#         [0.59166278]]])

# %% [markdown]
# ___________________![image.png](attachment:a2b037af-2ff0-42ce-9234-7ee8a9abb742.png)

# %%
model.predict(first_eval_batch)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# array([[0.56363946]], dtype=float32)

# %%
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 802ms/step
# array([[0.63285655]], dtype=float32)

# %% [markdown]
# _________________![image.png](attachment:b5adbbdd-43ed-4ee2-9417-382a709986b5.png)

# %%
scaled_test[0]
# Out:
# array([0.60665442])

# %%
# Out:
# array([0.60665442])

# %% [markdown]
# #### Try predicting the series!

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the next cell using 'Ctrl' + 'Enter' </h4> </html>

# %%
test_predictions = []

first_eval_batch = scaled_train[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))

current_batch
# Out:
# array([[[0.59621235],
#         [0.62693562],
#         [0.55844547],
#         [0.58834653],
#         [0.69254803],
#         [1.        ],
#         [0.44788555],
#         [0.49031162],
#         [0.59566421],
#         [0.58804506],
#         [0.63913175],
#         [0.59166278]]])

# %% [markdown]
# ____________________![image.png](attachment:2a703099-0587-49e4-9d06-5775208d1bb1.png)

# %%
for i in range(len(test)):
    current_pred = model.predict(current_batch)[0]
    test_predictions.append(current_pred)
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step

# %%
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step

# %% [markdown]
# ______________________![image.png](attachment:01302ec2-5ad1-4f49-a69b-8692f05a915a.png)

# %%
test_predictions
# Out:
# [array([0.56363946], dtype=float32),
#  array([0.6053408], dtype=float32),
#  array([0.5076307], dtype=float32),
#  array([0.5250902], dtype=float32),
#  array([0.644659], dtype=float32),
#  array([0.8567085], dtype=float32),
#  array([0.5033492], dtype=float32),
#  array([0.49022812], dtype=float32),
#  array([0.5207453], dtype=float32),
#  array([0.5337716], dtype=float32),
#  array([0.59068], dtype=float32),
#  array([0.5744256], dtype=float32),
#  array([0.5677062], dtype=float32),
#  array([0.5961029], dtype=float32),
#  array([0.4939079], dtype=float32),
#  array([0.49724674], dtype=float32),
#  array([0.6012393], dtype=float32),
#  array([0.79603225], dtype=float32)]

# %%
# Out:
# [array([0.63285655], dtype=float32),
#  array([0.655915], dtype=float32),
#  array([0.60953766], dtype=float32),
#  array([0.63251466], dtype=float32),
#  array([0.7280531], dtype=float32),
#  array([1.0275557], dtype=float32),
#  array([0.494833], dtype=float32),
#  array([0.53379714], dtype=float32),
#  array([0.6105526], dtype=float32),
#  array([0.62500674], dtype=float32),
#  array([0.66780484], dtype=float32),
#  array([0.6402486], dtype=float32),
#  array([0.66947997], dtype=float32),
#  array([0.68683314], dtype=float32),
#  array([0.65377283], dtype=float32),
#  array([0.6738984], dtype=float32),
#  array([0.7653416], dtype=float32),
#  array([1.0579401], dtype=float32)]

# %% [markdown]
# ### Inverse Transformations and Compare

# %% [markdown]
# _________________![image.png](attachment:9266da43-7b93-47a6-b135-724c546cf46b.png)

# %%
true_predictions = scaler.inverse_transform(test_predictions)
true_predictions
# Out:
# array([[23341.51304978],
#        [24863.06899709],
#        [21297.92156374],
#        [21934.96676922],
#        [26297.67230374],
#        [34034.72401047],
#        [21141.70171273],
#        [20662.95328718],
#        [21776.43293667],
#        [22251.72343868],
#        [24328.14127553],
#        [23735.06606877],
#        [23489.89711559],
#        [24526.00626975],
#        [20797.21749857],
#        [20919.04188442],
#        [24713.41920078],
#        [31820.82870311]])

# %%
# Out:
# array([[25867.03686076],
#        [26708.37140393],
#        [25016.20063967],
#        [25854.56223851],
#        [29340.47320271],
#        [40268.42497611],
#        [20830.97139931],
#        [22252.6564256 ],
#        [25053.23304337],
#        [25580.6207518 ],
#        [27142.1950959 ],
#        [26136.75054663],
#        [27203.31552541],
#        [27836.48089719],
#        [26630.20928335],
#        [27364.5308798 ],
#        [30701.01822633],
#        [41377.06135786]])

# %% [markdown]
# _____________![image.png](attachment:1689e362-0bac-4c6c-a993-55ff6789ceb7.png)

# %%
test['Predictions'] = true_predictions
# Out:
# C:\Users\Kalche\AppData\Local\Temp\ipykernel_9720\4269337381.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Predictions'] = true_predictions

# %%
# Out:
# C:\Users\vital\AppData\Local\Temp\ipykernel_18288\3095654106.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Predictions'] = true_predictions

# %% [markdown]
# ### Check and plot predictions

# %%
# Print the test variable

# ...
print(test)
# Out:
#                   Sales   Predictions
# observation_date
# 2023-07-01        24911  23341.513050
# 2023-08-01        26657  24863.068997
# 2023-09-01        23332  21297.921564
# 2023-10-01        23933  21934.966769
# 2023-11-01        28580  26297.672304
# 2023-12-01        40684  34034.724010
# 2024-01-01        19188  21141.701713
# 2024-02-01        22005  20662.953287
# 2024-03-01        24986  21776.432937
# 2024-04-01        23993  22251.723439
# 2024-05-01        27562  24328.141276
# 2024-06-01        25121  23735.066069
# 2024-07-01        25453  23489.897116
# 2024-08-01        27215  24526.006270
# 2024-09-01        23088  20797.217499
# 2024-10-01        25318  20919.041884
# 2024-11-01        29762  24713.419201
# 2024-12-01        41199  31820.828703

# %%
# Out:
#                   Sales   Predictions
# observation_date
# 2023-07-01        24911  25867.036861
# 2023-08-01        26657  26708.371404
# 2023-09-01        23332  25016.200640
# 2023-10-01        23933  25854.562239
# 2023-11-01        28580  29340.473203
# 2023-12-01        40684  40268.424976
# 2024-01-01        19188  20830.971399
# 2024-02-01        22005  22252.656426
# 2024-03-01        24986  25053.233043
# 2024-04-01        23993  25580.620752
# 2024-05-01        27562  27142.195096
# 2024-06-01        25121  26136.750547
# 2024-07-01        25453  27203.315525
# 2024-08-01        27215  27836.480897
# 2024-09-01        23088  26630.209283
# 2024-10-01        25318  27364.530880
# 2024-11-01        29762  30701.018226
# 2024-12-01        41199  41377.061358

# %% [markdown]
# _______________![image.png](attachment:f62685ae-fe3d-45e4-b14c-32c3f876ee6c.png)

# %%
test.plot(figsize=(8,5))
plt.show()

# %% [markdown]
# ### Retrain and Forecasting

# %% [markdown]
# _________________![image.png](attachment:ff8cd5dc-6662-482f-a78b-b18d5cdd5b85.png)

# %%
full_scaler = MinMaxScaler()
scaled_full_data = full_scaler.fit_transform(df)

# %% [markdown]
# ______________![image.png](attachment:e4738fb6-a3cd-4b5f-b347-5042ba0ab433.png)

# %%
print(scaled_full_data.max())
print(scaled_full_data.min())
# Out:
# 1.0
# 0.0

# %%
# Out:
# 1.0
# 0.0

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the next cell using 'Ctrl' + 'Enter' </h4> </html>

# %%
length = 12 # Length of the output sequences (in number of timesteps)
generator = TimeseriesGenerator(scaled_full_data, 
                                scaled_full_data, length=length, batch_size=1)

# %%
# Use any neural network model based on RNN
# You can also use the model created above
#
# Create the model
model2 = Sequential([
    LSTM(100, activation='relu', input_shape=(length, n_features), return_sequences=True),
    LSTM(32, activation='relu'),
    Dense(1) 
])
# Out:
# C:\Users\Kalche\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Out:
# C:\Users\vital\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the next cell using 'Ctrl' + 'Enter' </h4> </html>

# %%
model2.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 12, 100)             │          40,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 32)                  │          17,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 57,857 (226.00 KB)
#  Trainable params: 57,857 (226.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# your code to compile the model
model2.compile(optimizer='adam', loss='mse')
# ...

# %%
# Your code to create an object early-stop

# Use the patience parameter equal to the last digit in your SID.
# However,
# If the last digit of your SID = 0, then assign patience=10
# If the last digit of your SID = 1, then assign patience=11
# If the last digit of your SID = 2, then assign patience=12
# If the last digit of your SID = 3, then assign patience=13

# For example, your SID = 22984879, then patience=9
# One more example: your SID = 22984883, then patience=13

# LAST_DIGIT_IN_YOUR_SID = 4

early_stop = EarlyStopping(monitor='val_loss',patience=14)

# %% [markdown]
# ____________________![image.png](attachment:7b5b9107-f77e-4327-a987-878819f2ce45.png)

# %%
history_2 =  model2.fit(generator,  epochs=30,
                    validation_data=validation_generator,
                    callbacks=[early_stop])
# Out:
# Epoch 1/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0180 - val_loss: 0.0246
# Epoch 2/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0121 - val_loss: 0.0214
# Epoch 3/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0081 - val_loss: 0.0159
# Epoch 4/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0053 - val_loss: 0.0012
# Epoch 5/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0045 - val_loss: 0.0209
# Epoch 6/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0052 - val_loss: 0.0017
# Epoch 7/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0047 - val_loss: 0.0321
# Epoch 8/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0041 - val_loss: 0.0015
# Epoch 9/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0034 - val_loss: 0.0025
# Epoch 10/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0029 - val_loss: 4.7788e-04
# Epoch 11/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0031 - val_loss: 0.0012
# Epoch 12/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0031 - val_loss: 0.0026
# Epoch 13/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0031 - val_loss: 0.0029
# Epoch 14/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0035 - val_loss: 8.5654e-04
# Epoch 15/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0031 - val_loss: 0.0018
# Epoch 16/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0037 - val_loss: 0.0046
# Epoch 17/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0028 - val_loss: 0.0106
# Epoch 18/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0033 - val_loss: 8.2120e-04
# Epoch 19/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0029 - val_loss: 0.0029
# Epoch 20/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0028 - val_loss: 0.0013
# Epoch 21/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0029 - val_loss: 7.8443e-04
# Epoch 22/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0028 - val_loss: 5.0003e-04
# Epoch 23/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0027 - val_loss: 6.5311e-04
# Epoch 24/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0025 - val_loss: 9.5455e-04

# %%
# fit the model

#history_2 =  model2.fit(generator,  epochs=30,
                    validation_data=validation_generator,
                    callbacks=[early_stop])
# Out:
# Epoch 1/30
# C:\Users\vital\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - loss: 0.0338 - val_loss: 0.0284
# Epoch 2/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.0113 - val_loss: 0.0106
# Epoch 3/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - loss: 0.0104 - val_loss: 0.0036
# Epoch 4/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0056 - val_loss: 0.0116
# Epoch 5/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - loss: 0.0054 - val_loss: 6.5718e-04
# Epoch 6/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0040 - val_loss: 0.0084
# Epoch 7/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - loss: 0.0038 - val_loss: 8.4053e-04
# Epoch 8/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0055 - val_loss: 0.0159
# Epoch 9/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0051 - val_loss: 0.0015
# Epoch 10/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0037 - val_loss: 0.0025
# Epoch 11/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0048 - val_loss: 6.9735e-04
# Epoch 12/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - loss: 0.0040 - val_loss: 0.0030
# Epoch 13/30
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 13s 34ms/step - loss: 0.0020 - val_loss: 0.0032

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the next cell using 'Ctrl' + 'Enter' </h4> </html>

# %%
# print Loss for the neural network training process

history_dict = history_2.history

acc_values = history_dict['loss']
val_acc_values = history_dict['val_loss']
epochs = range(1, len(acc_values) + 1)

plt.figure(num=1, figsize=(15,7))
plt.plot(epochs, acc_values, 'bo', label='Training loss')
plt.plot(epochs, val_acc_values, 'b', label='Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss (mse)')
plt.legend()

plt.show()

# %%
# You can use the code created above to type the next cell code

# %% [markdown]
# _________________![image.png](attachment:02c09230-3aba-4573-8e73-6abd5e03c12a.png)

# %%
forecast=[]
periods = 12

first_eval_batch = scaled_full_data[-length:]
current_batch = first_eval_batch.reshape((1,length,n_features))


for i in range(periods):
    current_pred = model.predict(current_batch)[0]
    forecast.append(current_pred)
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step

# %%
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 711ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step

# %% [markdown]
# ______________________![image.png](attachment:3072f528-93a6-486e-b230-a376ae174ea2.png)

# %%
forecast = scaler.inverse_transform(forecast)
forecast
# Out:
# array([[21010.99655282],
#        [21280.3426984 ],
#        [21907.00108451],
#        [21510.99707192],
#        [24047.95160371],
#        [23020.07404739],
#        [24085.19061291],
#        [25087.96451432],
#        [21025.75905907],
#        [21682.96896076],
#        [25573.38303512],
#        [34525.77524948]])

# %%
# Out:
# array([[18620.61448288],
#        [20206.91406763],
#        [22167.73939276],
#        [21757.40348327],
#        [23828.92585731],
#        [22448.01823115],
#        [22479.73978627],
#        [23555.70857722],
#        [21352.45454019],
#        [22294.99097872],
#        [25707.46347636],
#        [37294.23667431]])

# %% [markdown]
# ### Creating new timestamp index with pandas.

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the 4 next cells using 'Ctrl' + 'Enter' </h4> </html>

# %%
df
# Out:
#                   Sales
# observation_date
# 1992-01-01         6938
# 1992-02-01         7524
# 1992-03-01         8475
# 1992-04-01         9401
# 1992-05-01         9558
# ...                 ...
# 2024-08-01        27215
# 2024-09-01        23088
# 2024-10-01        25318
# 2024-11-01        29762
# 2024-12-01        41199
#
# [396 rows x 1 columns]

# %% [markdown]
# ##### Forecast for next 12 months

# %% [markdown]
# __________________![image.png](attachment:de68283d-7631-47a5-8071-d3161809ea6c.png)

# %%
forecast_index = pd.date_range(start='2025-01-01',periods=periods, freq='MS')

# %% [markdown]
# __________________________![image.png](attachment:ee088abb-7456-4031-a648-67d7f8b3cc5e.png)

# %%
forecast_df = pd.DataFrame(data=forecast, index=forecast_index, columns=['Forecast'])

# %% [markdown]
# ________________________![image.png](attachment:886da6f6-c14f-41c3-a088-aaaed2bdd344.png)

# %%
forecast_df
# Out:
#                 Forecast
# 2025-01-01  21010.996553
# 2025-02-01  21280.342698
# 2025-03-01  21907.001085
# 2025-04-01  21510.997072
# 2025-05-01  24047.951604
# 2025-06-01  23020.074047
# 2025-07-01  24085.190613
# 2025-08-01  25087.964514
# 2025-09-01  21025.759059
# 2025-10-01  21682.968961
# 2025-11-01  25573.383035
# 2025-12-01  34525.775249

# %%
# Out:
#                 Forecast
# 2025-01-01  18620.614483
# 2025-02-01  20206.914068
# 2025-03-01  22167.739393
# 2025-04-01  21757.403483
# 2025-05-01  23828.925857
# 2025-06-01  22448.018231
# 2025-07-01  22479.739786
# 2025-08-01  23555.708577
# 2025-09-01  21352.454540
# 2025-10-01  22294.990979
# 2025-11-01  25707.463476
# 2025-12-01  37294.236674

# %% [markdown]
# __________________![image.png](attachment:a493f4a8-33ea-440d-ad45-8d5a273f8dfb.png)

# %%
df.plot(figsize=(8,5))
plt.show();

# %% [markdown]
# ____________________![image.png](attachment:f61a4158-30b1-457d-9aaa-2945b1ec8833.png)

# %%
forecast_df.plot(figsize=(8,5))
plt.show();

# %% [markdown]
# ### Joining pandas plots
#
# https://stackoverflow.com/questions/13872533/plot-different-dataframes-in-the-same-figure

# %% [markdown]
# ________________________![image.png](attachment:1ad9f420-c284-4442-8931-039f36b4390a.png)

# %%
ax = df.plot(figsize=(13,8))
forecast_df.plot(ax=ax)
plt.show();

# %% [markdown]
# _______![image.png](attachment:5611350d-0e2b-4867-9b54-de812a2abd8a.png)

# %%
ax = df.plot(figsize=(8,5))
forecast_df.plot(ax=ax)
plt.xlim('2023-01-01','2026-01-01')
plt.show();

# %% [markdown]
# ### Checking Forecast for last 12 months

# %% [markdown]
# _______________________![image.png](attachment:a673cbbb-1303-47a0-98f2-b462c1b68c7a.png)

# %%
forecast_index = pd.date_range(start='2024-01-01', periods=periods, freq='MS')
forecast_index
# Out:
# DatetimeIndex(['2024-01-01', '2024-02-01', '2024-03-01', '2024-04-01',
#                '2024-05-01', '2024-06-01', '2024-07-01', '2024-08-01',
#                '2024-09-01', '2024-10-01', '2024-11-01', '2024-12-01'],
#               dtype='datetime64[ns]', freq='MS')

# %%
# Out:
# DatetimeIndex(['2024-01-01', '2024-02-01', '2024-03-01', '2024-04-01',
#                '2024-05-01', '2024-06-01', '2024-07-01', '2024-08-01',
#                '2024-09-01', '2024-10-01', '2024-11-01', '2024-12-01'],
#               dtype='datetime64[ns]', freq='MS')

# %% [markdown]
# ________________________![image.png](attachment:609dc937-f0e4-4c79-afc0-37a15775ca93.png)

# %%
forecast_df = pd.DataFrame(data=forecast, index=forecast_index, columns=['Forecast'])

# %% [markdown]
# ___________________![image.png](attachment:ca844afe-754b-40bb-adc1-d40895c0cc67.png)

# %%
ax = df.plot(figsize=(12,6))
forecast_df.plot(ax=ax)
plt.xlim('2020-01-01','2025-01-01')
plt.show();

# %% [markdown]
# <html> <h2 style="font-style:bold; color:red;"> Lab Logbook requirements </h2> </html>
#
# ### 1. Record the 2nd model's code & plot the summary()
#
# ### 2. Copy your early-stop code and history_2 fit-training-process
#
# ### 3. Record the plot of validation and test loss of history_2.
#
# ### 4. Based on this analysis, determine the optimal number of epochs for training your model.
#
# ### 5. Record the plot of the Checking Forecast for the last 12 months (last graph).

# %% [markdown]
# ### Try the same example with a LSTM and/or GRU! (Optional)
# Hint: Use LSTM instead of SimpleRNN!
